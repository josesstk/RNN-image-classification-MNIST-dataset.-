# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical

# %%
# Load MNIST data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# x_train shape: (num_samples, 28, 28)
# Here 28 time steps, each with 28 features

# %%
model = Sequential([
    SimpleRNN(128, input_shape=(28, 28)),  # 128 RNN units
    Dense(10, activation='softmax')         # 10 classes output
])

model.summary()
# Out:
# C:\Users\TK\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 128)            │        20,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,386 (83.54 KB)
#  Trainable params: 21,386 (83.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2,
    verbose=2
)
# Out:
# Epoch 1/10
# 750/750 - 9s - 12ms/step - accuracy: 0.8791 - loss: 0.4086 - val_accuracy: 0.9418 - val_loss: 0.1995
# Epoch 2/10
# 750/750 - 9s - 12ms/step - accuracy: 0.9395 - loss: 0.2050 - val_accuracy: 0.9534 - val_loss: 0.1571
# Epoch 3/10
# 750/750 - 7s - 9ms/step - accuracy: 0.9519 - loss: 0.1646 - val_accuracy: 0.9577 - val_loss: 0.1471
# Epoch 4/10
# 750/750 - 7s - 9ms/step - accuracy: 0.9589 - loss: 0.1434 - val_accuracy: 0.9599 - val_loss: 0.1392
# Epoch 5/10
# 750/750 - 6s - 9ms/step - accuracy: 0.9621 - loss: 0.1296 - val_accuracy: 0.9482 - val_loss: 0.1802
# Epoch 6/10
# 750/750 - 7s - 9ms/step - accuracy: 0.9634 - loss: 0.1256 - val_accuracy: 0.9428 - val_loss: 0.1862
# Epoch 7/10
# 750/750 - 7s - 9ms/step - accuracy: 0.9663 - loss: 0.1166 - val_accuracy: 0.9682 - val_loss: 0.1142
# Epoch 8/10
# 750/750 - 11s - 14ms/step - accuracy: 0.9663 - loss: 0.1145 - val_accuracy: 0.9477 - val_loss: 0.1859
# Epoch 9/10
# 750/750 - 11s - 15ms/step - accuracy: 0.9681 - loss: 0.1101 - val_accuracy: 0.9662 - val_loss: 0.1244
# Epoch 10/10
# 750/750 - 7s - 9ms/step - accuracy: 0.9695 - loss: 0.1040 - val_accuracy: 0.9663 - val_loss: 0.1196

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 313/313 - 2s - 5ms/step - accuracy: 0.9661 - loss: 0.1178
# Test Accuracy: 0.9661
